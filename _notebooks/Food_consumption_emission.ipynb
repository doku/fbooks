# %%
library(tidyverse)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.1.1       v purrr   0.3.2
# v tibble  2.1.1       v dplyr   0.8.0.1
# v tidyr   0.8.3       v stringr 1.4.0
# v readr   1.3.1       v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
food_emmission <- read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-02-18/food_consumption.csv")
# Out:
# Parsed with column specification:
# cols(
#   country = col_character(),
#   food_category = col_character(),
#   consumption = col_double(),
#   co2_emmission = col_double()
# )

# %%
food_emmission %>% filter(food_category == "Eggs")
# Out:
#     country              food_category consumption co2_emmission
# 1   Argentina            Eggs          11.39       10.46
# 2   Australia            Eggs           8.51        7.82
# 3   Albania              Eggs          12.45       11.44
# 4   Iceland              Eggs           8.24        7.57
# 5   New Zealand          Eggs           9.91        9.10
# 6   USA                  Eggs          14.58       13.39
# 7   Uruguay              Eggs          13.14       12.07
# 8   Luxembourg           Eggs          14.64       13.45
# 9   Brazil               Eggs           8.98        8.25
# 10  Kazakhstan           Eggs           8.29        7.62
# 11  Sweden               Eggs          13.37       12.28
# 12  Bermuda              Eggs          14.92       13.71
# 13  Denmark              Eggs          15.35       14.10
# 14  Finland              Eggs           9.55        8.77
# 15  Ireland              Eggs           8.96        8.23
# ...

# %%
Sys.time()
# Out:
# [1] "2020-11-27 05:24:18 CST"
